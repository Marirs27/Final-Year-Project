# %%
import os
import pandas as pd
import pickle
import shutil
import numpy as np
import seaborn as sns
from sklearn.datasets import load_files
from keras.utils import np_utils
import matplotlib.pyplot as plt
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score



from PIL import ImageFile   
from sklearn.model_selection import train_test_split
from keras.preprocessing import image                  
from tqdm import tqdm

from keras.applications.vgg16 import VGG16

# %%
TEST_DIR = "./data/imgs/test"
TRAIN_DIR = "./data/imgs/train"
MODEL_PATH = os.path.join(os.getcwd(),"model","vgg16")
PICKLE_PATH = os.path.join(os.getcwd(),"pickle")
TEST_CSV = "csv_files/test.csv"
TRAIN_CSV = "csv_files/train.csv"

# %%
if not os.path.exists(TEST_DIR):
    print("Testing data does not exists")
if not os.path.exists(TRAIN_DIR):
    print("Training data does not exists")
if not os.path.exists(MODEL_PATH):
    print("Model path does not exists")
    os.makedirs(MODEL_PATH)
    print("Model path created")
else:
    shutil.rmtree(MODEL_PATH)
    os.makedirs(MODEL_PATH)
if not os.path.exists(PICKLE_PATH):
    os.makedirs(PICKLE_PATH)

# %%
data_train = pd.read_csv(TRAIN_CSV)
data_test = pd.read_csv(TEST_CSV)

# %%
labels_list = list(set(data_train['ClassName'].values.tolist()))
labels_id = {label_name:id for id,label_name in enumerate(labels_list)}
print(labels_id)
data_train['ClassName'].replace(labels_id,inplace=True)

labels = to_categorical(data_train['ClassName'])
print(labels.shape)

with open(os.path.join(PICKLE_PATH,"labels_list_vgg16.pkl"),"wb") as handle:
    pickle.dump(labels_id,handle)
# Out:
# {'c0': 0, 'c9': 1, 'c6': 2, 'c1': 3, 'c5': 4, 'c7': 5, 'c2': 6, 'c4': 7, 'c3': 8, 'c8': 9}
# (22424, 10)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(data_train.iloc[:,0],labels,test_size = 0.2,random_state=42)
def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(64, 64))
    # convert PIL.Image.Image type to 3D tensor with shape (64, 64, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 64, 64, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True                 
# pre-process the data for Keras
train_tensors = paths_to_tensor(xtrain).astype('float32')/255 - 0.5
valid_tensors = paths_to_tensor(xtest).astype('float32')/255 - 0.5
# Out:
# 100%|██████████| 17939/17939 [00:48<00:00, 366.58it/s]
# 100%|██████████| 4485/4485 [00:09<00:00, 474.45it/s]

# %%
model = VGG16(include_top=False)
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_vgg16 = model.predict(train_tensors,verbose=1)
valid_vgg16 = model.predict(valid_tensors,verbose=1)
# Out:
# 561/561 [==============================] - 222s 379ms/step
# 141/141 [==============================] - 56s 395ms/step

# %%
print("Train shape",train_vgg16.shape)
print("Validation shape",valid_vgg16.shape)
# Out:
# Train shape (17939, 2, 2, 512)
# Validation shape (4485, 2, 2, 512)

# %%
train_features = train_vgg16[0]
valid_features = valid_vgg16[0]

# %%
print("Train features shape",train_features.shape)
print("Validation features shape",valid_features.shape)
# Out:
# Train features shape (2, 2, 512)
# Validation features shape (2, 2, 512)

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_features.shape))
VGG16_model.add(Dense(10, activation='softmax', kernel_initializer='glorot_normal'))

VGG16_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                5130
# =================================================================
# Total params: 5,130
# Trainable params: 5,130
# Non-trainable params: 0
# _________________________________________________________________

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
filepath = os.path.join(MODEL_PATH,"distracted-{epoch:02d}-{val_accuracy:.2f}.hdf5")
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max',period=1)
callbacks_list = [checkpoint]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
model_history = VGG16_model.fit(train_vgg16,ytrain,validation_data = (valid_vgg16, ytest),epochs=200, batch_size=16, shuffle=True,callbacks=callbacks_list)
# Out:
# Epoch 1/200
# 1122/1122 [==============================] - 16s 2ms/step - loss: 1.9874 - accuracy: 0.3476 - val_loss: 1.4288 - val_accuracy: 0.5940
#
# Epoch 00001: val_accuracy improved from -inf to 0.59398, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-01-0.59.hdf5
# Epoch 2/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 1.3217 - accuracy: 0.6394 - val_loss: 1.1415 - val_accuracy: 0.6885
#
# Epoch 00002: val_accuracy improved from 0.59398 to 0.68852, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-02-0.69.hdf5
# Epoch 3/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 1.0597 - accuracy: 0.7154 - val_loss: 0.9769 - val_accuracy: 0.7344
#
# Epoch 00003: val_accuracy improved from 0.68852 to 0.73445, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-03-0.73.hdf5
# Epoch 4/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.9128 - accuracy: 0.7604 - val_loss: 0.8675 - val_accuracy: 0.7672
#
# Epoch 00004: val_accuracy improved from 0.73445 to 0.76722, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-04-0.77.hdf5
# Epoch 5/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.8120 - accuracy: 0.7810 - val_loss: 0.8099 - val_accuracy: 0.7732
#
# Epoch 00005: val_accuracy improved from 0.76722 to 0.77324, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-05-0.77.hdf5
# Epoch 6/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.7362 - accuracy: 0.8030 - val_loss: 0.7371 - val_accuracy: 0.7915
#
# Epoch 00006: val_accuracy improved from 0.77324 to 0.79153, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-06-0.79.hdf5
# Epoch 7/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.6891 - accuracy: 0.8168 - val_loss: 0.6806 - val_accuracy: 0.8221
#
# Epoch 00007: val_accuracy improved from 0.79153 to 0.82207, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-07-0.82.hdf5
# Epoch 8/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.6351 - accuracy: 0.8300 - val_loss: 0.6427 - val_accuracy: 0.8317
#
# Epoch 00008: val_accuracy improved from 0.82207 to 0.83166, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-08-0.83.hdf5
# Epoch 9/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.6024 - accuracy: 0.8398 - val_loss: 0.6195 - val_accuracy: 0.8366
#
# Epoch 00009: val_accuracy improved from 0.83166 to 0.83657, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-09-0.84.hdf5
# Epoch 10/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.5740 - accuracy: 0.8492 - val_loss: 0.6027 - val_accuracy: 0.8301
#
# Epoch 00010: val_accuracy did not improve from 0.83657
# Epoch 11/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.5450 - accuracy: 0.8548 - val_loss: 0.5637 - val_accuracy: 0.8508
#
# Epoch 00011: val_accuracy improved from 0.83657 to 0.85084, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-11-0.85.hdf5
# Epoch 12/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.5199 - accuracy: 0.8592 - val_loss: 0.5558 - val_accuracy: 0.8491
#
# Epoch 00012: val_accuracy did not improve from 0.85084
# Epoch 13/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.4891 - accuracy: 0.8687 - val_loss: 0.5242 - val_accuracy: 0.8651
#
# Epoch 00013: val_accuracy improved from 0.85084 to 0.86511, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-13-0.87.hdf5
# Epoch 14/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.4788 - accuracy: 0.8699 - val_loss: 0.5107 - val_accuracy: 0.8638
#
# Epoch 00014: val_accuracy did not improve from 0.86511
# Epoch 15/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.4609 - accuracy: 0.8808 - val_loss: 0.5087 - val_accuracy: 0.8604
#
# Epoch 00015: val_accuracy did not improve from 0.86511
# Epoch 16/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.4537 - accuracy: 0.8761 - val_loss: 0.4923 - val_accuracy: 0.8633
#
# Epoch 00016: val_accuracy did not improve from 0.86511
# Epoch 17/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.4334 - accuracy: 0.8865 - val_loss: 0.4735 - val_accuracy: 0.8765
#
# Epoch 00017: val_accuracy improved from 0.86511 to 0.87648, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-17-0.88.hdf5
# Epoch 18/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.4337 - accuracy: 0.8808 - val_loss: 0.4605 - val_accuracy: 0.8809
#
# Epoch 00018: val_accuracy improved from 0.87648 to 0.88094, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-18-0.88.hdf5
# Epoch 19/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.4173 - accuracy: 0.8889 - val_loss: 0.4625 - val_accuracy: 0.8727
#
# Epoch 00019: val_accuracy did not improve from 0.88094
# Epoch 20/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.4023 - accuracy: 0.8935 - val_loss: 0.4448 - val_accuracy: 0.8816
#
# Epoch 00020: val_accuracy improved from 0.88094 to 0.88161, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-20-0.88.hdf5
# Epoch 21/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.4039 - accuracy: 0.8912 - val_loss: 0.4441 - val_accuracy: 0.8816
#
# Epoch 00021: val_accuracy did not improve from 0.88161
# Epoch 22/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.3887 - accuracy: 0.8950 - val_loss: 0.4294 - val_accuracy: 0.8852
#
# Epoch 00022: val_accuracy improved from 0.88161 to 0.88517, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-22-0.89.hdf5
# Epoch 23/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.3844 - accuracy: 0.8938 - val_loss: 0.4304 - val_accuracy: 0.8838
#
# Epoch 00023: val_accuracy did not improve from 0.88517
# Epoch 24/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.3756 - accuracy: 0.8963 - val_loss: 0.4159 - val_accuracy: 0.8878
#
# Epoch 00024: val_accuracy improved from 0.88517 to 0.88785, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-24-0.89.hdf5
# Epoch 25/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.3720 - accuracy: 0.8994 - val_loss: 0.4141 - val_accuracy: 0.8838
#
# Epoch 00025: val_accuracy did not improve from 0.88785
# Epoch 26/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.3614 - accuracy: 0.9015 - val_loss: 0.4053 - val_accuracy: 0.8890
#
# Epoch 00026: val_accuracy improved from 0.88785 to 0.88896, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-26-0.89.hdf5
# Epoch 27/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.3545 - accuracy: 0.9009 - val_loss: 0.4105 - val_accuracy: 0.8874
#
# Epoch 00027: val_accuracy did not improve from 0.88896
# Epoch 28/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.3515 - accuracy: 0.9012 - val_loss: 0.3981 - val_accuracy: 0.8896
#
# Epoch 00028: val_accuracy improved from 0.88896 to 0.88963, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-28-0.89.hdf5
# Epoch 29/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.3385 - accuracy: 0.9105 - val_loss: 0.3926 - val_accuracy: 0.8907
#
# Epoch 00029: val_accuracy improved from 0.88963 to 0.89075, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-29-0.89.hdf5
# Epoch 30/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.3411 - accuracy: 0.9065 - val_loss: 0.3956 - val_accuracy: 0.8954
#
# Epoch 00030: val_accuracy improved from 0.89075 to 0.89543, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-30-0.90.hdf5
# Epoch 31/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.3320 - accuracy: 0.9103 - val_loss: 0.3926 - val_accuracy: 0.8874
#
# Epoch 00031: val_accuracy did not improve from 0.89543
# Epoch 32/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.3261 - accuracy: 0.9105 - val_loss: 0.3799 - val_accuracy: 0.8974
#
# Epoch 00032: val_accuracy improved from 0.89543 to 0.89744, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-32-0.90.hdf5
# Epoch 33/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.3213 - accuracy: 0.9112 - val_loss: 0.3786 - val_accuracy: 0.8914
#
# Epoch 00033: val_accuracy did not improve from 0.89744
# Epoch 34/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.3252 - accuracy: 0.9130 - val_loss: 0.3814 - val_accuracy: 0.8936
#
# Epoch 00034: val_accuracy did not improve from 0.89744
# Epoch 35/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.3151 - accuracy: 0.9119 - val_loss: 0.3684 - val_accuracy: 0.8999
#
# Epoch 00035: val_accuracy improved from 0.89744 to 0.89989, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-35-0.90.hdf5
# Epoch 36/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.3083 - accuracy: 0.9185 - val_loss: 0.3714 - val_accuracy: 0.8936
#
# Epoch 00036: val_accuracy did not improve from 0.89989
# Epoch 37/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.3017 - accuracy: 0.9186 - val_loss: 0.3662 - val_accuracy: 0.9001
#
# Epoch 00037: val_accuracy improved from 0.89989 to 0.90011, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-37-0.90.hdf5
# Epoch 38/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.3026 - accuracy: 0.9161 - val_loss: 0.3642 - val_accuracy: 0.9006
#
# Epoch 00038: val_accuracy improved from 0.90011 to 0.90056, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-38-0.90.hdf5
# Epoch 39/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.3012 - accuracy: 0.9166 - val_loss: 0.3640 - val_accuracy: 0.8983
#
# Epoch 00039: val_accuracy did not improve from 0.90056
# Epoch 40/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.3119 - accuracy: 0.9114 - val_loss: 0.3579 - val_accuracy: 0.8986
#
# Epoch 00040: val_accuracy did not improve from 0.90056
# Epoch 41/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2946 - accuracy: 0.9199 - val_loss: 0.3534 - val_accuracy: 0.9023
#
# Epoch 00041: val_accuracy improved from 0.90056 to 0.90234, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-41-0.90.hdf5
# Epoch 42/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2929 - accuracy: 0.9202 - val_loss: 0.3512 - val_accuracy: 0.9028
#
# Epoch 00042: val_accuracy improved from 0.90234 to 0.90279, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-42-0.90.hdf5
# Epoch 43/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2890 - accuracy: 0.9192 - val_loss: 0.3501 - val_accuracy: 0.8988
#
# Epoch 00043: val_accuracy did not improve from 0.90279
# Epoch 44/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2857 - accuracy: 0.9220 - val_loss: 0.3480 - val_accuracy: 0.9014
#
# Epoch 00044: val_accuracy did not improve from 0.90279
# Epoch 45/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2781 - accuracy: 0.9260 - val_loss: 0.3480 - val_accuracy: 0.9041
#
# Epoch 00045: val_accuracy improved from 0.90279 to 0.90412, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-45-0.90.hdf5
# Epoch 46/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2890 - accuracy: 0.9219 - val_loss: 0.3426 - val_accuracy: 0.9046
#
# Epoch 00046: val_accuracy improved from 0.90412 to 0.90457, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-46-0.90.hdf5
# Epoch 47/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2719 - accuracy: 0.9230 - val_loss: 0.3391 - val_accuracy: 0.9028
#
# Epoch 00047: val_accuracy did not improve from 0.90457
# Epoch 48/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2810 - accuracy: 0.9221 - val_loss: 0.3426 - val_accuracy: 0.9035
#
# Epoch 00048: val_accuracy did not improve from 0.90457
# Epoch 49/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2795 - accuracy: 0.9212 - val_loss: 0.3481 - val_accuracy: 0.9046
#
# Epoch 00049: val_accuracy did not improve from 0.90457
# Epoch 50/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2656 - accuracy: 0.9264 - val_loss: 0.3337 - val_accuracy: 0.9048
#
# Epoch 00050: val_accuracy improved from 0.90457 to 0.90479, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-50-0.90.hdf5
# Epoch 51/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2709 - accuracy: 0.9248 - val_loss: 0.3322 - val_accuracy: 0.9059
#
# Epoch 00051: val_accuracy improved from 0.90479 to 0.90591, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-51-0.91.hdf5
# Epoch 52/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2649 - accuracy: 0.9221 - val_loss: 0.3319 - val_accuracy: 0.9072
#
# Epoch 00052: val_accuracy improved from 0.90591 to 0.90725, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-52-0.91.hdf5
# Epoch 53/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2589 - accuracy: 0.9291 - val_loss: 0.3326 - val_accuracy: 0.9026
#
# Epoch 00053: val_accuracy did not improve from 0.90725
# Epoch 54/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2548 - accuracy: 0.9299 - val_loss: 0.3312 - val_accuracy: 0.9066
#
# Epoch 00054: val_accuracy did not improve from 0.90725
# Epoch 55/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2602 - accuracy: 0.9288 - val_loss: 0.3274 - val_accuracy: 0.9068
#
# Epoch 00055: val_accuracy did not improve from 0.90725
# Epoch 56/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2638 - accuracy: 0.9270 - val_loss: 0.3284 - val_accuracy: 0.9061
#
# Epoch 00056: val_accuracy did not improve from 0.90725
# Epoch 57/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2670 - accuracy: 0.9242 - val_loss: 0.3294 - val_accuracy: 0.9068
#
# Epoch 00057: val_accuracy did not improve from 0.90725
# Epoch 58/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2645 - accuracy: 0.9235 - val_loss: 0.3261 - val_accuracy: 0.9093
#
# Epoch 00058: val_accuracy improved from 0.90725 to 0.90925, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-58-0.91.hdf5
# Epoch 59/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2576 - accuracy: 0.9281 - val_loss: 0.3242 - val_accuracy: 0.9086
#
# Epoch 00059: val_accuracy did not improve from 0.90925
# Epoch 60/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2606 - accuracy: 0.9268 - val_loss: 0.3295 - val_accuracy: 0.9046
#
# Epoch 00060: val_accuracy did not improve from 0.90925
# Epoch 61/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2530 - accuracy: 0.9310 - val_loss: 0.3193 - val_accuracy: 0.9093
#
# Epoch 00061: val_accuracy did not improve from 0.90925
# Epoch 62/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2476 - accuracy: 0.9304 - val_loss: 0.3213 - val_accuracy: 0.9126
#
# Epoch 00062: val_accuracy improved from 0.90925 to 0.91260, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-62-0.91.hdf5
# Epoch 63/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2520 - accuracy: 0.9303 - val_loss: 0.3243 - val_accuracy: 0.9050
#
# Epoch 00063: val_accuracy did not improve from 0.91260
# Epoch 64/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2499 - accuracy: 0.9285 - val_loss: 0.3180 - val_accuracy: 0.9088
#
# Epoch 00064: val_accuracy did not improve from 0.91260
# Epoch 65/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2506 - accuracy: 0.9287 - val_loss: 0.3255 - val_accuracy: 0.9079
#
# Epoch 00065: val_accuracy did not improve from 0.91260
# Epoch 66/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2543 - accuracy: 0.9282 - val_loss: 0.3176 - val_accuracy: 0.9075
#
# Epoch 00066: val_accuracy did not improve from 0.91260
# Epoch 67/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2426 - accuracy: 0.9328 - val_loss: 0.3243 - val_accuracy: 0.9059
#
# Epoch 00067: val_accuracy did not improve from 0.91260
# Epoch 68/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2391 - accuracy: 0.9305 - val_loss: 0.3182 - val_accuracy: 0.9086
#
# Epoch 00068: val_accuracy did not improve from 0.91260
# Epoch 69/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2411 - accuracy: 0.9338 - val_loss: 0.3115 - val_accuracy: 0.9099
#
# Epoch 00069: val_accuracy did not improve from 0.91260
# Epoch 70/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2451 - accuracy: 0.9325 - val_loss: 0.3142 - val_accuracy: 0.9110
#
# Epoch 00070: val_accuracy did not improve from 0.91260
# Epoch 71/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2439 - accuracy: 0.9312 - val_loss: 0.3142 - val_accuracy: 0.9088
#
# Epoch 00071: val_accuracy did not improve from 0.91260
# Epoch 72/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2401 - accuracy: 0.9343 - val_loss: 0.3214 - val_accuracy: 0.9039
#
# Epoch 00072: val_accuracy did not improve from 0.91260
# Epoch 73/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2367 - accuracy: 0.9329 - val_loss: 0.3182 - val_accuracy: 0.9097
#
# Epoch 00073: val_accuracy did not improve from 0.91260
# Epoch 74/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2370 - accuracy: 0.9363 - val_loss: 0.3110 - val_accuracy: 0.9124
#
# Epoch 00074: val_accuracy did not improve from 0.91260
# Epoch 75/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2309 - accuracy: 0.9334 - val_loss: 0.3116 - val_accuracy: 0.9086
#
# Epoch 00075: val_accuracy did not improve from 0.91260
# Epoch 76/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2404 - accuracy: 0.9317 - val_loss: 0.3057 - val_accuracy: 0.9117
#
# Epoch 00076: val_accuracy did not improve from 0.91260
# Epoch 77/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2310 - accuracy: 0.9375 - val_loss: 0.3114 - val_accuracy: 0.9126
#
# Epoch 00077: val_accuracy did not improve from 0.91260
# Epoch 78/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2268 - accuracy: 0.9363 - val_loss: 0.3124 - val_accuracy: 0.9108
#
# Epoch 00078: val_accuracy did not improve from 0.91260
# Epoch 79/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2314 - accuracy: 0.9351 - val_loss: 0.3073 - val_accuracy: 0.9095
#
# Epoch 00079: val_accuracy did not improve from 0.91260
# Epoch 80/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2316 - accuracy: 0.9356 - val_loss: 0.3080 - val_accuracy: 0.9122
#
# Epoch 00080: val_accuracy did not improve from 0.91260
# Epoch 81/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2447 - accuracy: 0.9291 - val_loss: 0.3028 - val_accuracy: 0.9122
#
# Epoch 00081: val_accuracy did not improve from 0.91260
# Epoch 82/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2376 - accuracy: 0.9327 - val_loss: 0.3059 - val_accuracy: 0.9128
#
# Epoch 00082: val_accuracy improved from 0.91260 to 0.91282, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-82-0.91.hdf5
# Epoch 83/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2256 - accuracy: 0.9366 - val_loss: 0.3108 - val_accuracy: 0.9088
#
# Epoch 00083: val_accuracy did not improve from 0.91282
# Epoch 84/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2273 - accuracy: 0.9359 - val_loss: 0.3097 - val_accuracy: 0.9115
#
# Epoch 00084: val_accuracy did not improve from 0.91282
# Epoch 85/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2267 - accuracy: 0.9377 - val_loss: 0.3067 - val_accuracy: 0.9153
#
# Epoch 00085: val_accuracy improved from 0.91282 to 0.91527, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-85-0.92.hdf5
# Epoch 86/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2400 - accuracy: 0.9340 - val_loss: 0.3030 - val_accuracy: 0.9130
#
# Epoch 00086: val_accuracy did not improve from 0.91527
# Epoch 87/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2218 - accuracy: 0.9372 - val_loss: 0.3074 - val_accuracy: 0.9101
#
# Epoch 00087: val_accuracy did not improve from 0.91527
# Epoch 88/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2144 - accuracy: 0.9395 - val_loss: 0.3050 - val_accuracy: 0.9110
#
# Epoch 00088: val_accuracy did not improve from 0.91527
# Epoch 89/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2224 - accuracy: 0.9357 - val_loss: 0.3070 - val_accuracy: 0.9095
#
# Epoch 00089: val_accuracy did not improve from 0.91527
# Epoch 90/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2196 - accuracy: 0.9371 - val_loss: 0.3051 - val_accuracy: 0.9122
#
# Epoch 00090: val_accuracy did not improve from 0.91527
# Epoch 91/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2201 - accuracy: 0.9375 - val_loss: 0.3058 - val_accuracy: 0.9088
#
# Epoch 00091: val_accuracy did not improve from 0.91527
# Epoch 92/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2215 - accuracy: 0.9384 - val_loss: 0.3034 - val_accuracy: 0.9110
#
# Epoch 00092: val_accuracy did not improve from 0.91527
# Epoch 93/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2141 - accuracy: 0.9415 - val_loss: 0.2971 - val_accuracy: 0.9137
#
# Epoch 00093: val_accuracy did not improve from 0.91527
# Epoch 94/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2226 - accuracy: 0.9368 - val_loss: 0.3065 - val_accuracy: 0.9086
#
# Epoch 00094: val_accuracy did not improve from 0.91527
# Epoch 95/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2119 - accuracy: 0.9413 - val_loss: 0.3144 - val_accuracy: 0.9075
#
# Epoch 00095: val_accuracy did not improve from 0.91527
# Epoch 96/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2144 - accuracy: 0.9409 - val_loss: 0.3151 - val_accuracy: 0.9079
#
# Epoch 00096: val_accuracy did not improve from 0.91527
# Epoch 97/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2180 - accuracy: 0.9370 - val_loss: 0.2980 - val_accuracy: 0.9115
#
# Epoch 00097: val_accuracy did not improve from 0.91527
# Epoch 98/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2294 - accuracy: 0.9376 - val_loss: 0.2972 - val_accuracy: 0.9130
#
# Epoch 00098: val_accuracy did not improve from 0.91527
# Epoch 99/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2187 - accuracy: 0.9394 - val_loss: 0.3034 - val_accuracy: 0.9110
#
# Epoch 00099: val_accuracy did not improve from 0.91527
# Epoch 100/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2077 - accuracy: 0.9402 - val_loss: 0.2985 - val_accuracy: 0.9144
#
# Epoch 00100: val_accuracy did not improve from 0.91527
# Epoch 101/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2122 - accuracy: 0.9401 - val_loss: 0.3015 - val_accuracy: 0.9155
#
# Epoch 00101: val_accuracy improved from 0.91527 to 0.91550, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-101-0.92.hdf5
# Epoch 102/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2108 - accuracy: 0.9385 - val_loss: 0.2972 - val_accuracy: 0.9148
#
# Epoch 00102: val_accuracy did not improve from 0.91550
# Epoch 103/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2110 - accuracy: 0.9411 - val_loss: 0.2986 - val_accuracy: 0.9142
#
# Epoch 00103: val_accuracy did not improve from 0.91550
# Epoch 104/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2167 - accuracy: 0.9403 - val_loss: 0.2959 - val_accuracy: 0.9135
#
# Epoch 00104: val_accuracy did not improve from 0.91550
# Epoch 105/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2123 - accuracy: 0.9404 - val_loss: 0.2973 - val_accuracy: 0.9144
#
# Epoch 00105: val_accuracy did not improve from 0.91550
# Epoch 106/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2173 - accuracy: 0.9409 - val_loss: 0.2968 - val_accuracy: 0.9168
#
# Epoch 00106: val_accuracy improved from 0.91550 to 0.91683, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-106-0.92.hdf5
# Epoch 107/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2109 - accuracy: 0.9378 - val_loss: 0.2965 - val_accuracy: 0.9142
#
# Epoch 00107: val_accuracy did not improve from 0.91683
# Epoch 108/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2038 - accuracy: 0.9422 - val_loss: 0.2963 - val_accuracy: 0.9155
#
# Epoch 00108: val_accuracy did not improve from 0.91683
# Epoch 109/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2120 - accuracy: 0.9415 - val_loss: 0.3000 - val_accuracy: 0.9146
#
# Epoch 00109: val_accuracy did not improve from 0.91683
# Epoch 110/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2146 - accuracy: 0.9365 - val_loss: 0.3000 - val_accuracy: 0.9151
#
# Epoch 00110: val_accuracy did not improve from 0.91683
# Epoch 111/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2057 - accuracy: 0.9406 - val_loss: 0.2983 - val_accuracy: 0.9155
#
# Epoch 00111: val_accuracy did not improve from 0.91683
# Epoch 112/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2060 - accuracy: 0.9429 - val_loss: 0.2936 - val_accuracy: 0.9177
#
# Epoch 00112: val_accuracy improved from 0.91683 to 0.91773, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-112-0.92.hdf5
# Epoch 113/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2088 - accuracy: 0.9417 - val_loss: 0.3028 - val_accuracy: 0.9106
#
# Epoch 00113: val_accuracy did not improve from 0.91773
# Epoch 114/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2118 - accuracy: 0.9434 - val_loss: 0.2963 - val_accuracy: 0.9151
#
# Epoch 00114: val_accuracy did not improve from 0.91773
# Epoch 115/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2079 - accuracy: 0.9430 - val_loss: 0.3069 - val_accuracy: 0.9117
#
# Epoch 00115: val_accuracy did not improve from 0.91773
# Epoch 116/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2103 - accuracy: 0.9407 - val_loss: 0.2957 - val_accuracy: 0.9139
#
# Epoch 00116: val_accuracy did not improve from 0.91773
# Epoch 117/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2051 - accuracy: 0.9423 - val_loss: 0.2932 - val_accuracy: 0.9144
#
# Epoch 00117: val_accuracy did not improve from 0.91773
# Epoch 118/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2129 - accuracy: 0.9390 - val_loss: 0.2977 - val_accuracy: 0.9137
#
# Epoch 00118: val_accuracy did not improve from 0.91773
# Epoch 119/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2106 - accuracy: 0.9395 - val_loss: 0.2963 - val_accuracy: 0.9130
#
# Epoch 00119: val_accuracy did not improve from 0.91773
# Epoch 120/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2061 - accuracy: 0.9408 - val_loss: 0.2987 - val_accuracy: 0.9162
#
# Epoch 00120: val_accuracy did not improve from 0.91773
# Epoch 121/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1927 - accuracy: 0.9452 - val_loss: 0.2964 - val_accuracy: 0.9128
#
# Epoch 00121: val_accuracy did not improve from 0.91773
# Epoch 122/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1972 - accuracy: 0.9450 - val_loss: 0.2933 - val_accuracy: 0.9144
#
# Epoch 00122: val_accuracy did not improve from 0.91773
# Epoch 123/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1970 - accuracy: 0.9447 - val_loss: 0.2912 - val_accuracy: 0.9164
#
# Epoch 00123: val_accuracy did not improve from 0.91773
# Epoch 124/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2089 - accuracy: 0.9413 - val_loss: 0.2907 - val_accuracy: 0.9159
#
# Epoch 00124: val_accuracy did not improve from 0.91773
# Epoch 125/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1996 - accuracy: 0.9446 - val_loss: 0.3056 - val_accuracy: 0.9122
#
# Epoch 00125: val_accuracy did not improve from 0.91773
# Epoch 126/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1942 - accuracy: 0.9456 - val_loss: 0.3003 - val_accuracy: 0.9157
#
# Epoch 00126: val_accuracy did not improve from 0.91773
# Epoch 127/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1977 - accuracy: 0.9426 - val_loss: 0.2935 - val_accuracy: 0.9139
#
# Epoch 00127: val_accuracy did not improve from 0.91773
# Epoch 128/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1950 - accuracy: 0.9420 - val_loss: 0.2951 - val_accuracy: 0.9135
#
# Epoch 00128: val_accuracy did not improve from 0.91773
# Epoch 129/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2032 - accuracy: 0.9417 - val_loss: 0.2975 - val_accuracy: 0.9173
#
# Epoch 00129: val_accuracy did not improve from 0.91773
# Epoch 130/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1960 - accuracy: 0.9457 - val_loss: 0.3023 - val_accuracy: 0.9101
#
# Epoch 00130: val_accuracy did not improve from 0.91773
# Epoch 131/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2013 - accuracy: 0.9431 - val_loss: 0.2951 - val_accuracy: 0.9117
#
# Epoch 00131: val_accuracy did not improve from 0.91773
# Epoch 132/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2004 - accuracy: 0.9443 - val_loss: 0.2932 - val_accuracy: 0.9184
#
# Epoch 00132: val_accuracy improved from 0.91773 to 0.91839, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\vgg16\distracted-132-0.92.hdf5
# Epoch 133/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1969 - accuracy: 0.9458 - val_loss: 0.2915 - val_accuracy: 0.9135
#
# Epoch 00133: val_accuracy did not improve from 0.91839
# Epoch 134/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.2053 - accuracy: 0.9410 - val_loss: 0.2966 - val_accuracy: 0.9148
#
# Epoch 00134: val_accuracy did not improve from 0.91839
# Epoch 135/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2055 - accuracy: 0.9465 - val_loss: 0.2955 - val_accuracy: 0.9130
#
# Epoch 00135: val_accuracy did not improve from 0.91839
# Epoch 136/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1888 - accuracy: 0.9461 - val_loss: 0.2964 - val_accuracy: 0.9155
#
# Epoch 00136: val_accuracy did not improve from 0.91839
# Epoch 137/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1877 - accuracy: 0.9485 - val_loss: 0.2910 - val_accuracy: 0.9153
#
# Epoch 00137: val_accuracy did not improve from 0.91839
# Epoch 138/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1973 - accuracy: 0.9447 - val_loss: 0.2959 - val_accuracy: 0.9146
#
# Epoch 00138: val_accuracy did not improve from 0.91839
# Epoch 139/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1949 - accuracy: 0.9455 - val_loss: 0.2911 - val_accuracy: 0.9146
#
# Epoch 00139: val_accuracy did not improve from 0.91839
# Epoch 140/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1979 - accuracy: 0.9450 - val_loss: 0.2943 - val_accuracy: 0.9162
#
# Epoch 00140: val_accuracy did not improve from 0.91839
# Epoch 141/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1926 - accuracy: 0.9445 - val_loss: 0.2940 - val_accuracy: 0.9148
#
# Epoch 00141: val_accuracy did not improve from 0.91839
# Epoch 142/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1983 - accuracy: 0.9420 - val_loss: 0.2939 - val_accuracy: 0.9162
#
# Epoch 00142: val_accuracy did not improve from 0.91839
# Epoch 143/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1985 - accuracy: 0.9442 - val_loss: 0.2916 - val_accuracy: 0.9164
#
# Epoch 00143: val_accuracy did not improve from 0.91839
# Epoch 144/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1979 - accuracy: 0.9422 - val_loss: 0.2953 - val_accuracy: 0.9137
#
# Epoch 00144: val_accuracy did not improve from 0.91839
# Epoch 145/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1860 - accuracy: 0.9467 - val_loss: 0.2960 - val_accuracy: 0.9142
#
# Epoch 00145: val_accuracy did not improve from 0.91839
# Epoch 146/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2034 - accuracy: 0.9419 - val_loss: 0.2967 - val_accuracy: 0.9133
#
# Epoch 00146: val_accuracy did not improve from 0.91839
# Epoch 147/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1996 - accuracy: 0.9444 - val_loss: 0.2967 - val_accuracy: 0.9146
#
# Epoch 00147: val_accuracy did not improve from 0.91839
# Epoch 148/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1941 - accuracy: 0.9461 - val_loss: 0.2944 - val_accuracy: 0.9126
#
# Epoch 00148: val_accuracy did not improve from 0.91839
# Epoch 149/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1924 - accuracy: 0.9456 - val_loss: 0.2933 - val_accuracy: 0.9168
#
# Epoch 00149: val_accuracy did not improve from 0.91839
# Epoch 150/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1902 - accuracy: 0.9467 - val_loss: 0.2939 - val_accuracy: 0.9130
#
# Epoch 00150: val_accuracy did not improve from 0.91839
# Epoch 151/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1968 - accuracy: 0.9434 - val_loss: 0.2967 - val_accuracy: 0.9142
#
# Epoch 00151: val_accuracy did not improve from 0.91839
# Epoch 152/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1946 - accuracy: 0.9457 - val_loss: 0.2914 - val_accuracy: 0.9148
#
# Epoch 00152: val_accuracy did not improve from 0.91839
# Epoch 153/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1950 - accuracy: 0.9458 - val_loss: 0.2995 - val_accuracy: 0.9128
#
# Epoch 00153: val_accuracy did not improve from 0.91839
# Epoch 154/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1954 - accuracy: 0.9448 - val_loss: 0.2952 - val_accuracy: 0.9135
#
# Epoch 00154: val_accuracy did not improve from 0.91839
# Epoch 155/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1905 - accuracy: 0.9474 - val_loss: 0.2935 - val_accuracy: 0.9157
#
# Epoch 00155: val_accuracy did not improve from 0.91839
# Epoch 156/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1983 - accuracy: 0.9441 - val_loss: 0.2923 - val_accuracy: 0.9184
#
# Epoch 00156: val_accuracy did not improve from 0.91839
# Epoch 157/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1878 - accuracy: 0.9462 - val_loss: 0.2960 - val_accuracy: 0.9171
#
# Epoch 00157: val_accuracy did not improve from 0.91839
# Epoch 158/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1895 - accuracy: 0.9478 - val_loss: 0.3029 - val_accuracy: 0.9124
#
# Epoch 00158: val_accuracy did not improve from 0.91839
# Epoch 159/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1868 - accuracy: 0.9449 - val_loss: 0.2966 - val_accuracy: 0.9166
#
# Epoch 00159: val_accuracy did not improve from 0.91839
# Epoch 160/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1923 - accuracy: 0.9465 - val_loss: 0.2907 - val_accuracy: 0.9179
#
# Epoch 00160: val_accuracy did not improve from 0.91839
# Epoch 161/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1895 - accuracy: 0.9460 - val_loss: 0.2914 - val_accuracy: 0.9151
#
# Epoch 00161: val_accuracy did not improve from 0.91839
# Epoch 162/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1850 - accuracy: 0.9471 - val_loss: 0.2928 - val_accuracy: 0.9162
#
# Epoch 00162: val_accuracy did not improve from 0.91839
# Epoch 163/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1878 - accuracy: 0.9477 - val_loss: 0.2956 - val_accuracy: 0.9159
#
# Epoch 00163: val_accuracy did not improve from 0.91839
# Epoch 164/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1920 - accuracy: 0.9484 - val_loss: 0.2951 - val_accuracy: 0.9168
#
# Epoch 00164: val_accuracy did not improve from 0.91839
# Epoch 165/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1910 - accuracy: 0.9476 - val_loss: 0.2947 - val_accuracy: 0.9153
#
# Epoch 00165: val_accuracy did not improve from 0.91839
# Epoch 166/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1825 - accuracy: 0.9483 - val_loss: 0.3004 - val_accuracy: 0.9097
#
# Epoch 00166: val_accuracy did not improve from 0.91839
# Epoch 167/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1929 - accuracy: 0.9477 - val_loss: 0.3036 - val_accuracy: 0.9093
#
# Epoch 00167: val_accuracy did not improve from 0.91839
# Epoch 168/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1911 - accuracy: 0.9470 - val_loss: 0.2960 - val_accuracy: 0.9142
#
# Epoch 00168: val_accuracy did not improve from 0.91839
# Epoch 169/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1845 - accuracy: 0.9479 - val_loss: 0.2933 - val_accuracy: 0.9133
#
# Epoch 00169: val_accuracy did not improve from 0.91839
# Epoch 170/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1825 - accuracy: 0.9465 - val_loss: 0.2930 - val_accuracy: 0.9148
#
# Epoch 00170: val_accuracy did not improve from 0.91839
# Epoch 171/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1861 - accuracy: 0.9469 - val_loss: 0.2962 - val_accuracy: 0.9162
#
# Epoch 00171: val_accuracy did not improve from 0.91839
# Epoch 172/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1768 - accuracy: 0.9492 - val_loss: 0.2947 - val_accuracy: 0.9139
#
# Epoch 00172: val_accuracy did not improve from 0.91839
# Epoch 173/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1875 - accuracy: 0.9486 - val_loss: 0.2977 - val_accuracy: 0.9162
#
# Epoch 00173: val_accuracy did not improve from 0.91839
# Epoch 174/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1900 - accuracy: 0.9476 - val_loss: 0.2923 - val_accuracy: 0.9159
#
# Epoch 00174: val_accuracy did not improve from 0.91839
# Epoch 175/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1842 - accuracy: 0.9467 - val_loss: 0.3105 - val_accuracy: 0.9113
#
# Epoch 00175: val_accuracy did not improve from 0.91839
# Epoch 176/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1835 - accuracy: 0.9469 - val_loss: 0.2924 - val_accuracy: 0.9153
#
# Epoch 00176: val_accuracy did not improve from 0.91839
# Epoch 177/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1833 - accuracy: 0.9470 - val_loss: 0.2925 - val_accuracy: 0.9142
#
# Epoch 00177: val_accuracy did not improve from 0.91839
# Epoch 178/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1828 - accuracy: 0.9488 - val_loss: 0.2965 - val_accuracy: 0.9137
#
# Epoch 00178: val_accuracy did not improve from 0.91839
# Epoch 179/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1997 - accuracy: 0.9453 - val_loss: 0.2947 - val_accuracy: 0.9146
#
# Epoch 00179: val_accuracy did not improve from 0.91839
# Epoch 180/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1777 - accuracy: 0.9495 - val_loss: 0.3031 - val_accuracy: 0.9146
#
# Epoch 00180: val_accuracy did not improve from 0.91839
# Epoch 181/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1878 - accuracy: 0.9495 - val_loss: 0.2952 - val_accuracy: 0.9122
#
# Epoch 00181: val_accuracy did not improve from 0.91839
# Epoch 182/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1799 - accuracy: 0.9492 - val_loss: 0.2986 - val_accuracy: 0.9144
#
# Epoch 00182: val_accuracy did not improve from 0.91839
# Epoch 183/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1925 - accuracy: 0.9460 - val_loss: 0.2980 - val_accuracy: 0.9139
#
# Epoch 00183: val_accuracy did not improve from 0.91839
# Epoch 184/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1791 - accuracy: 0.9482 - val_loss: 0.2949 - val_accuracy: 0.9173
#
# Epoch 00184: val_accuracy did not improve from 0.91839
# Epoch 185/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1921 - accuracy: 0.9461 - val_loss: 0.2967 - val_accuracy: 0.9157
#
# Epoch 00185: val_accuracy did not improve from 0.91839
# Epoch 186/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1870 - accuracy: 0.9473 - val_loss: 0.2957 - val_accuracy: 0.9162
#
# Epoch 00186: val_accuracy did not improve from 0.91839
# Epoch 187/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1932 - accuracy: 0.9464 - val_loss: 0.2951 - val_accuracy: 0.9175
#
# Epoch 00187: val_accuracy did not improve from 0.91839
# Epoch 188/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1870 - accuracy: 0.9471 - val_loss: 0.2943 - val_accuracy: 0.9157
#
# Epoch 00188: val_accuracy did not improve from 0.91839
# Epoch 189/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1922 - accuracy: 0.9490 - val_loss: 0.2955 - val_accuracy: 0.9162
#
# Epoch 00189: val_accuracy did not improve from 0.91839
# Epoch 190/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1866 - accuracy: 0.9487 - val_loss: 0.2967 - val_accuracy: 0.9166
#
# Epoch 00190: val_accuracy did not improve from 0.91839
# Epoch 191/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1898 - accuracy: 0.9468 - val_loss: 0.2956 - val_accuracy: 0.9146
#
# Epoch 00191: val_accuracy did not improve from 0.91839
# Epoch 192/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1872 - accuracy: 0.9483 - val_loss: 0.2982 - val_accuracy: 0.9153
#
# Epoch 00192: val_accuracy did not improve from 0.91839
# Epoch 193/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1797 - accuracy: 0.9491 - val_loss: 0.2969 - val_accuracy: 0.9146
#
# Epoch 00193: val_accuracy did not improve from 0.91839
# Epoch 194/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1833 - accuracy: 0.9509 - val_loss: 0.2995 - val_accuracy: 0.9151
#
# Epoch 00194: val_accuracy did not improve from 0.91839
# Epoch 195/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1817 - accuracy: 0.9480 - val_loss: 0.2980 - val_accuracy: 0.9137
#
# Epoch 00195: val_accuracy did not improve from 0.91839
# Epoch 196/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1831 - accuracy: 0.9488 - val_loss: 0.2937 - val_accuracy: 0.9153
#
# Epoch 00196: val_accuracy did not improve from 0.91839
# Epoch 197/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1797 - accuracy: 0.9496 - val_loss: 0.3005 - val_accuracy: 0.9157
#
# Epoch 00197: val_accuracy did not improve from 0.91839
# Epoch 198/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1872 - accuracy: 0.9481 - val_loss: 0.2956 - val_accuracy: 0.9146
#
# Epoch 00198: val_accuracy did not improve from 0.91839
# Epoch 199/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1823 - accuracy: 0.9501 - val_loss: 0.2950 - val_accuracy: 0.9144
#
# Epoch 00199: val_accuracy did not improve from 0.91839
# Epoch 200/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1888 - accuracy: 0.9476 - val_loss: 0.2957 - val_accuracy: 0.9153
#
# Epoch 00200: val_accuracy did not improve from 0.91839

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(model_history.history['loss'], color='b', label="Training loss")
ax1.plot(model_history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, 400, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(model_history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(model_history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, 400, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    fig.savefig(os.path.join(MODEL_PATH,"confusion_matrix.png"))
    return fig

# %%
def print_heatmap(n_labels, n_predictions, class_names):
    labels = n_labels #sess.run(tf.argmax(n_labels, 1))
    predictions = n_predictions #sess.run(tf.argmax(n_predictions, 1))

#     confusion_matrix = sess.run(tf.contrib.metrics.confusion_matrix(labels, predictions))
    matrix = confusion_matrix(labels.argmax(axis=1),predictions.argmax(axis=1))
    row_sum = np.sum(matrix, axis = 1)
    w, h = matrix.shape

    c_m = np.zeros((w, h))

    for i in range(h):
        c_m[i] = matrix[i] * 100 / row_sum[i]

    c = c_m.astype(dtype = np.uint8)

    
    heatmap = print_confusion_matrix(c, class_names, figsize=(18,10), fontsize=20)

# %%
class_names = list()
for name,idx in labels_id.items():
    class_names.append(name)
# print(class_names)
ypred = VGG16_model.predict(valid_vgg16,verbose=1)
# Out:
# 141/141 [==============================] - 0s 807us/step

# %%
print_heatmap(ytest,ypred,class_names)

# %%
ypred_class = np.argmax(ypred,axis=1)
# print(ypred_class[:10])
ytest = np.argmax(ytest,axis=1)

# %%
accuracy = accuracy_score(ytest,ypred_class)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(ytest, ypred_class,average='weighted')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(ytest,ypred_class,average='weighted')
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(ytest,ypred_class,average='weighted')
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.915273
# Precision: 0.916092
# Recall: 0.915273
# F1 score: 0.915447

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils.vis_utils import plot_model
from keras.models import load_model

model = load_model('model/vgg16/distracted-132-0.92.hdf5')
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')
