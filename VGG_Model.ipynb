# %%
import os
import pandas as pd
import pickle
import shutil
import numpy as np
import seaborn as sns
from sklearn.datasets import load_files
from keras.utils import np_utils
import matplotlib.pyplot as plt
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

from PIL import ImageFile   
from sklearn.model_selection import train_test_split
from keras.preprocessing import image                  
from tqdm import tqdm

from keras.applications.vgg16 import VGG16

# %%
TEST_DIR = "./data/imgs/test"
TRAIN_DIR = "./data/imgs/train"
MODEL_PATH = os.path.join(os.getcwd(),"model","trained")
PICKLE_PATH = os.path.join(os.getcwd(),"pickle")
TEST_CSV = "csv_files/test.csv"
TRAIN_CSV = "csv_files/train.csv"

# %%
if not os.path.exists(TEST_DIR):
    print("Testing data does not exists")
if not os.path.exists(TRAIN_DIR):
    print("Training data does not exists")
if not os.path.exists(MODEL_PATH):
    print("Model path does not exists")
    os.makedirs(MODEL_PATH)
    print("Model path created")
else:
    shutil.rmtree(MODEL_PATH)
    os.makedirs(MODEL_PATH)
if not os.path.exists(PICKLE_PATH):
    os.makedirs(PICKLE_PATH)
# Out:
# Model path does not exists
# Model path created

# %%
data_train = pd.read_csv(TRAIN_CSV)
data_test = pd.read_csv(TEST_CSV)

# %%
labels_list = list(set(data_train['ClassName'].values.tolist()))
labels_id = {label_name:id for id,label_name in enumerate(labels_list)}
print(labels_id)
data_train['ClassName'].replace(labels_id,inplace=True)

labels = to_categorical(data_train['ClassName'])
print(labels.shape)

with open(os.path.join(PICKLE_PATH,"labels_list_vgg16.pkl"),"wb") as handle:
    pickle.dump(labels_id,handle)
# Out:
# {'c9': 0, 'c7': 1, 'c2': 2, 'c3': 3, 'c0': 4, 'c1': 5, 'c5': 6, 'c6': 7, 'c8': 8, 'c4': 9}
# (22424, 10)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(data_train.iloc[:,0],labels,test_size = 0.2,random_state=42)
def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(64, 64))
    # convert PIL.Image.Image type to 3D tensor with shape (64, 64, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 64, 64, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True                 
# pre-process the data for Keras
train_tensors = paths_to_tensor(xtrain).astype('float32')/255 - 0.5
valid_tensors = paths_to_tensor(xtest).astype('float32')/255 - 0.5
# Out:
# 100%|██████████| 17939/17939 [00:50<00:00, 351.99it/s]
# 100%|██████████| 4485/4485 [00:14<00:00, 311.67it/s]

# %%
model = VGG16(include_top=False)
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_vgg16 = model.predict(train_tensors,verbose=1)
valid_vgg16 = model.predict(valid_tensors,verbose=1)
# Out:
# 561/561 [==============================] - 240s 417ms/step
# 141/141 [==============================] - 61s 431ms/step

# %%
print("Train shape",train_vgg16.shape)
print("Validation shape",valid_vgg16.shape)
# Out:
# Train shape (17939, 2, 2, 512)
# Validation shape (4485, 2, 2, 512)

# %%
train_features = train_vgg16[0]
valid_features = valid_vgg16[0]

# %%
print("Train features shape",train_features.shape)
print("Validation features shape",valid_features.shape)
# Out:
# Train features shape (2, 2, 512)
# Validation features shape (2, 2, 512)

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_features.shape))
VGG16_model.add(Dense(10, activation='softmax', kernel_initializer='glorot_normal'))

VGG16_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                5130
# =================================================================
# Total params: 5,130
# Trainable params: 5,130
# Non-trainable params: 0
# _________________________________________________________________

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
filepath = os.path.join(MODEL_PATH,"distracted-{epoch:02d}-{val_accuracy:.2f}.hdf5")
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max',period=1)
callbacks_list = [checkpoint]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
model_history = VGG16_model.fit(train_vgg16,ytrain,validation_data = (valid_vgg16, ytest),epochs=200, batch_size=16, shuffle=True,callbacks=callbacks_list)
# Out:
# Epoch 1/200
# 1122/1122 [==============================] - 12s 3ms/step - loss: 2.0079 - accuracy: 0.3240 - val_loss: 1.4468 - val_accuracy: 0.5817
#
# Epoch 00001: val_accuracy improved from -inf to 0.58172, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-01-0.58.hdf5
# Epoch 2/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 1.3422 - accuracy: 0.6226 - val_loss: 1.1645 - val_accuracy: 0.6586
#
# Epoch 00002: val_accuracy improved from 0.58172 to 0.65864, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-02-0.66.hdf5
# Epoch 3/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 1.0720 - accuracy: 0.7081 - val_loss: 0.9932 - val_accuracy: 0.7213
#
# Epoch 00003: val_accuracy improved from 0.65864 to 0.72129, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-03-0.72.hdf5
# Epoch 4/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.9222 - accuracy: 0.7522 - val_loss: 0.8743 - val_accuracy: 0.7572
#
# Epoch 00004: val_accuracy improved from 0.72129 to 0.75719, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-04-0.76.hdf5
# Epoch 5/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.8281 - accuracy: 0.7800 - val_loss: 0.7977 - val_accuracy: 0.7784
#
# Epoch 00005: val_accuracy improved from 0.75719 to 0.77837, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-05-0.78.hdf5
# Epoch 6/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.7439 - accuracy: 0.8019 - val_loss: 0.7374 - val_accuracy: 0.8013
#
# Epoch 00006: val_accuracy improved from 0.77837 to 0.80134, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-06-0.80.hdf5
# Epoch 7/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.6913 - accuracy: 0.8180 - val_loss: 0.6858 - val_accuracy: 0.8145
#
# Epoch 00007: val_accuracy improved from 0.80134 to 0.81449, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-07-0.81.hdf5
# Epoch 8/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.6403 - accuracy: 0.8264 - val_loss: 0.6520 - val_accuracy: 0.8261
#
# Epoch 00008: val_accuracy improved from 0.81449 to 0.82609, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-08-0.83.hdf5
# Epoch 9/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.6055 - accuracy: 0.8376 - val_loss: 0.6192 - val_accuracy: 0.8392
#
# Epoch 00009: val_accuracy improved from 0.82609 to 0.83924, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-09-0.84.hdf5
# Epoch 10/200
# 1122/1122 [==============================] - 3s 2ms/step - loss: 0.5653 - accuracy: 0.8486 - val_loss: 0.6092 - val_accuracy: 0.8241
#
# Epoch 00010: val_accuracy did not improve from 0.83924
# Epoch 11/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.8572 - val_loss: 0.5616 - val_accuracy: 0.8540
#
# Epoch 00011: val_accuracy improved from 0.83924 to 0.85396, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-11-0.85.hdf5
# Epoch 12/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.5187 - accuracy: 0.8588 - val_loss: 0.5426 - val_accuracy: 0.8582
#
# Epoch 00012: val_accuracy improved from 0.85396 to 0.85819, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-12-0.86.hdf5
# Epoch 13/200
# 1122/1122 [==============================] - 3s 2ms/step - loss: 0.5001 - accuracy: 0.8668 - val_loss: 0.5276 - val_accuracy: 0.8635
#
# Epoch 00013: val_accuracy improved from 0.85819 to 0.86355, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-13-0.86.hdf5
# Epoch 14/200
# 1122/1122 [==============================] - 3s 2ms/step - loss: 0.4830 - accuracy: 0.8706 - val_loss: 0.5097 - val_accuracy: 0.8673
#
# Epoch 00014: val_accuracy improved from 0.86355 to 0.86734, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-14-0.87.hdf5
# Epoch 15/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.4696 - accuracy: 0.8749 - val_loss: 0.4975 - val_accuracy: 0.8658
#
# Epoch 00015: val_accuracy did not improve from 0.86734
# Epoch 16/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.4568 - accuracy: 0.8772 - val_loss: 0.4887 - val_accuracy: 0.8658
#
# Epoch 00016: val_accuracy did not improve from 0.86734
# Epoch 17/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.4526 - accuracy: 0.8766 - val_loss: 0.4708 - val_accuracy: 0.8716
#
# Epoch 00017: val_accuracy improved from 0.86734 to 0.87157, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-17-0.87.hdf5
# Epoch 18/200
# 1122/1122 [==============================] - 3s 2ms/step - loss: 0.4274 - accuracy: 0.8870 - val_loss: 0.4597 - val_accuracy: 0.8787
#
# Epoch 00018: val_accuracy improved from 0.87157 to 0.87871, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-18-0.88.hdf5
# Epoch 19/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.4142 - accuracy: 0.8875 - val_loss: 0.4573 - val_accuracy: 0.8792
#
# Epoch 00019: val_accuracy improved from 0.87871 to 0.87915, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-19-0.88.hdf5
# Epoch 20/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.4140 - accuracy: 0.8874 - val_loss: 0.4490 - val_accuracy: 0.8805
#
# Epoch 00020: val_accuracy improved from 0.87915 to 0.88049, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-20-0.88.hdf5
# Epoch 21/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.4062 - accuracy: 0.8899 - val_loss: 0.4451 - val_accuracy: 0.8827
#
# Epoch 00021: val_accuracy improved from 0.88049 to 0.88272, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-21-0.88.hdf5
# Epoch 22/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3904 - accuracy: 0.8947 - val_loss: 0.4463 - val_accuracy: 0.8787
#
# Epoch 00022: val_accuracy did not improve from 0.88272
# Epoch 23/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3855 - accuracy: 0.8930 - val_loss: 0.4248 - val_accuracy: 0.8870
#
# Epoch 00023: val_accuracy improved from 0.88272 to 0.88696, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-23-0.89.hdf5
# Epoch 24/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3772 - accuracy: 0.8978 - val_loss: 0.4225 - val_accuracy: 0.8843
#
# Epoch 00024: val_accuracy did not improve from 0.88696
# Epoch 25/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3655 - accuracy: 0.9004 - val_loss: 0.4117 - val_accuracy: 0.8903
#
# Epoch 00025: val_accuracy improved from 0.88696 to 0.89030, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-25-0.89.hdf5
# Epoch 26/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3689 - accuracy: 0.9020 - val_loss: 0.4059 - val_accuracy: 0.8892
#
# Epoch 00026: val_accuracy did not improve from 0.89030
# Epoch 27/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3519 - accuracy: 0.9056 - val_loss: 0.4153 - val_accuracy: 0.8872
#
# Epoch 00027: val_accuracy did not improve from 0.89030
# Epoch 28/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3508 - accuracy: 0.9010 - val_loss: 0.4158 - val_accuracy: 0.8789
#
# Epoch 00028: val_accuracy did not improve from 0.89030
# Epoch 29/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3557 - accuracy: 0.9011 - val_loss: 0.3942 - val_accuracy: 0.8914
#
# Epoch 00029: val_accuracy improved from 0.89030 to 0.89142, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-29-0.89.hdf5
# Epoch 30/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3437 - accuracy: 0.9078 - val_loss: 0.3861 - val_accuracy: 0.8959
#
# Epoch 00030: val_accuracy improved from 0.89142 to 0.89588, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-30-0.90.hdf5
# Epoch 31/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3487 - accuracy: 0.9049 - val_loss: 0.3838 - val_accuracy: 0.8941
#
# Epoch 00031: val_accuracy did not improve from 0.89588
# Epoch 32/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3393 - accuracy: 0.9100 - val_loss: 0.3862 - val_accuracy: 0.8988
#
# Epoch 00032: val_accuracy improved from 0.89588 to 0.89877, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-32-0.90.hdf5
# Epoch 33/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3307 - accuracy: 0.9088 - val_loss: 0.3746 - val_accuracy: 0.8972
#
# Epoch 00033: val_accuracy did not improve from 0.89877
# Epoch 34/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3177 - accuracy: 0.9104 - val_loss: 0.3712 - val_accuracy: 0.8963
#
# Epoch 00034: val_accuracy did not improve from 0.89877
# Epoch 35/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3103 - accuracy: 0.9169 - val_loss: 0.3726 - val_accuracy: 0.9003
#
# Epoch 00035: val_accuracy improved from 0.89877 to 0.90033, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-35-0.90.hdf5
# Epoch 36/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3118 - accuracy: 0.9130 - val_loss: 0.3648 - val_accuracy: 0.8994
#
# Epoch 00036: val_accuracy did not improve from 0.90033
# Epoch 37/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3186 - accuracy: 0.9130 - val_loss: 0.3672 - val_accuracy: 0.8994
#
# Epoch 00037: val_accuracy did not improve from 0.90033
# Epoch 38/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3053 - accuracy: 0.9146 - val_loss: 0.3655 - val_accuracy: 0.8974
#
# Epoch 00038: val_accuracy did not improve from 0.90033
# Epoch 39/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3035 - accuracy: 0.9182 - val_loss: 0.3668 - val_accuracy: 0.8939
#
# Epoch 00039: val_accuracy did not improve from 0.90033
# Epoch 40/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3055 - accuracy: 0.9176 - val_loss: 0.3544 - val_accuracy: 0.9023
#
# Epoch 00040: val_accuracy improved from 0.90033 to 0.90234, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-40-0.90.hdf5
# Epoch 41/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.3036 - accuracy: 0.9155 - val_loss: 0.3513 - val_accuracy: 0.9026
#
# Epoch 00041: val_accuracy improved from 0.90234 to 0.90256, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-41-0.90.hdf5
# Epoch 42/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2907 - accuracy: 0.9201 - val_loss: 0.3511 - val_accuracy: 0.9003
#
# Epoch 00042: val_accuracy did not improve from 0.90256
# Epoch 43/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2896 - accuracy: 0.9207 - val_loss: 0.3544 - val_accuracy: 0.8974
#
# Epoch 00043: val_accuracy did not improve from 0.90256
# Epoch 44/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2924 - accuracy: 0.9195 - val_loss: 0.3550 - val_accuracy: 0.8979
#
# Epoch 00044: val_accuracy did not improve from 0.90256
# Epoch 45/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2779 - accuracy: 0.9229 - val_loss: 0.3449 - val_accuracy: 0.9001
#
# Epoch 00045: val_accuracy did not improve from 0.90256
# Epoch 46/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2909 - accuracy: 0.9188 - val_loss: 0.3481 - val_accuracy: 0.9008
#
# Epoch 00046: val_accuracy did not improve from 0.90256
# Epoch 47/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2773 - accuracy: 0.9238 - val_loss: 0.3375 - val_accuracy: 0.9037
#
# Epoch 00047: val_accuracy improved from 0.90256 to 0.90368, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-47-0.90.hdf5
# Epoch 48/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2794 - accuracy: 0.9226 - val_loss: 0.3398 - val_accuracy: 0.9052
#
# Epoch 00048: val_accuracy improved from 0.90368 to 0.90524, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-48-0.91.hdf5
# Epoch 49/200
# 1122/1122 [==============================] - 3s 2ms/step - loss: 0.2755 - accuracy: 0.9220 - val_loss: 0.3332 - val_accuracy: 0.9077
#
# Epoch 00049: val_accuracy improved from 0.90524 to 0.90769, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-49-0.91.hdf5
# Epoch 50/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2748 - accuracy: 0.9256 - val_loss: 0.3363 - val_accuracy: 0.9043
#
# Epoch 00050: val_accuracy did not improve from 0.90769
# Epoch 51/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2688 - accuracy: 0.9262 - val_loss: 0.3338 - val_accuracy: 0.9050
#
# Epoch 00051: val_accuracy did not improve from 0.90769
# Epoch 52/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2694 - accuracy: 0.9257 - val_loss: 0.3299 - val_accuracy: 0.9090
#
# Epoch 00052: val_accuracy improved from 0.90769 to 0.90903, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-52-0.91.hdf5
# Epoch 53/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2687 - accuracy: 0.9246 - val_loss: 0.3320 - val_accuracy: 0.9081
#
# Epoch 00053: val_accuracy did not improve from 0.90903
# Epoch 54/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2704 - accuracy: 0.9275 - val_loss: 0.3343 - val_accuracy: 0.9048
#
# Epoch 00054: val_accuracy did not improve from 0.90903
# Epoch 55/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2565 - accuracy: 0.9295 - val_loss: 0.3310 - val_accuracy: 0.9064
#
# Epoch 00055: val_accuracy did not improve from 0.90903
# Epoch 56/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2589 - accuracy: 0.9266 - val_loss: 0.3295 - val_accuracy: 0.9064
#
# Epoch 00056: val_accuracy did not improve from 0.90903
# Epoch 57/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2635 - accuracy: 0.9281 - val_loss: 0.3260 - val_accuracy: 0.9072
#
# Epoch 00057: val_accuracy did not improve from 0.90903
# Epoch 58/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2573 - accuracy: 0.9288 - val_loss: 0.3246 - val_accuracy: 0.9108
#
# Epoch 00058: val_accuracy improved from 0.90903 to 0.91081, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-58-0.91.hdf5
# Epoch 59/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2577 - accuracy: 0.9291 - val_loss: 0.3234 - val_accuracy: 0.9041
#
# Epoch 00059: val_accuracy did not improve from 0.91081
# Epoch 60/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2461 - accuracy: 0.9321 - val_loss: 0.3237 - val_accuracy: 0.9075
#
# Epoch 00060: val_accuracy did not improve from 0.91081
# Epoch 61/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2553 - accuracy: 0.9301 - val_loss: 0.3226 - val_accuracy: 0.9106
#
# Epoch 00061: val_accuracy did not improve from 0.91081
# Epoch 62/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2406 - accuracy: 0.9329 - val_loss: 0.3276 - val_accuracy: 0.9064
#
# Epoch 00062: val_accuracy did not improve from 0.91081
# Epoch 63/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2477 - accuracy: 0.9287 - val_loss: 0.3236 - val_accuracy: 0.9093
#
# Epoch 00063: val_accuracy did not improve from 0.91081
# Epoch 64/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2432 - accuracy: 0.9297 - val_loss: 0.3178 - val_accuracy: 0.9128
#
# Epoch 00064: val_accuracy improved from 0.91081 to 0.91282, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-64-0.91.hdf5
# Epoch 65/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2561 - accuracy: 0.9298 - val_loss: 0.3179 - val_accuracy: 0.9084
#
# Epoch 00065: val_accuracy did not improve from 0.91282
# Epoch 66/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2571 - accuracy: 0.9271 - val_loss: 0.3170 - val_accuracy: 0.9064
#
# Epoch 00066: val_accuracy did not improve from 0.91282
# Epoch 67/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2453 - accuracy: 0.9310 - val_loss: 0.3290 - val_accuracy: 0.9008
#
# Epoch 00067: val_accuracy did not improve from 0.91282
# Epoch 68/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2466 - accuracy: 0.9309 - val_loss: 0.3128 - val_accuracy: 0.9115
#
# Epoch 00068: val_accuracy did not improve from 0.91282
# Epoch 69/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2382 - accuracy: 0.9345 - val_loss: 0.3157 - val_accuracy: 0.9115
#
# Epoch 00069: val_accuracy did not improve from 0.91282
# Epoch 70/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2437 - accuracy: 0.9320 - val_loss: 0.3126 - val_accuracy: 0.9113
#
# Epoch 00070: val_accuracy did not improve from 0.91282
# Epoch 71/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2418 - accuracy: 0.9337 - val_loss: 0.3129 - val_accuracy: 0.9126
#
# Epoch 00071: val_accuracy did not improve from 0.91282
# Epoch 72/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2392 - accuracy: 0.9339 - val_loss: 0.3143 - val_accuracy: 0.9110
#
# Epoch 00072: val_accuracy did not improve from 0.91282
# Epoch 73/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2503 - accuracy: 0.9297 - val_loss: 0.3095 - val_accuracy: 0.9108
#
# Epoch 00073: val_accuracy did not improve from 0.91282
# Epoch 74/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2409 - accuracy: 0.9314 - val_loss: 0.3158 - val_accuracy: 0.9095
#
# Epoch 00074: val_accuracy did not improve from 0.91282
# Epoch 75/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2358 - accuracy: 0.9355 - val_loss: 0.3109 - val_accuracy: 0.9115
#
# Epoch 00075: val_accuracy did not improve from 0.91282
# Epoch 76/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2357 - accuracy: 0.9347 - val_loss: 0.3146 - val_accuracy: 0.9101
#
# Epoch 00076: val_accuracy did not improve from 0.91282
# Epoch 77/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2286 - accuracy: 0.9348 - val_loss: 0.3052 - val_accuracy: 0.9122
#
# Epoch 00077: val_accuracy did not improve from 0.91282
# Epoch 78/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2399 - accuracy: 0.9322 - val_loss: 0.3069 - val_accuracy: 0.9122
#
# Epoch 00078: val_accuracy did not improve from 0.91282
# Epoch 79/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2332 - accuracy: 0.9363 - val_loss: 0.3062 - val_accuracy: 0.9095
#
# Epoch 00079: val_accuracy did not improve from 0.91282
# Epoch 80/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2295 - accuracy: 0.9375 - val_loss: 0.3190 - val_accuracy: 0.9061
#
# Epoch 00080: val_accuracy did not improve from 0.91282
# Epoch 81/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2309 - accuracy: 0.9357 - val_loss: 0.3049 - val_accuracy: 0.9097
#
# Epoch 00081: val_accuracy did not improve from 0.91282
# Epoch 82/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2251 - accuracy: 0.9368 - val_loss: 0.3112 - val_accuracy: 0.9064
#
# Epoch 00082: val_accuracy did not improve from 0.91282
# Epoch 83/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2257 - accuracy: 0.9348 - val_loss: 0.3099 - val_accuracy: 0.9095
#
# Epoch 00083: val_accuracy did not improve from 0.91282
# Epoch 84/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2253 - accuracy: 0.9391 - val_loss: 0.3121 - val_accuracy: 0.9088
#
# Epoch 00084: val_accuracy did not improve from 0.91282
# Epoch 85/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2249 - accuracy: 0.9359 - val_loss: 0.3047 - val_accuracy: 0.9122
#
# Epoch 00085: val_accuracy did not improve from 0.91282
# Epoch 86/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2298 - accuracy: 0.9373 - val_loss: 0.3036 - val_accuracy: 0.9119
#
# Epoch 00086: val_accuracy did not improve from 0.91282
# Epoch 87/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2215 - accuracy: 0.9384 - val_loss: 0.3101 - val_accuracy: 0.9075
#
# Epoch 00087: val_accuracy did not improve from 0.91282
# Epoch 88/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2251 - accuracy: 0.9380 - val_loss: 0.3052 - val_accuracy: 0.9104
#
# Epoch 00088: val_accuracy did not improve from 0.91282
# Epoch 89/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2179 - accuracy: 0.9394 - val_loss: 0.3039 - val_accuracy: 0.9124
#
# Epoch 00089: val_accuracy did not improve from 0.91282
# Epoch 90/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2150 - accuracy: 0.9391 - val_loss: 0.3040 - val_accuracy: 0.9122
#
# Epoch 00090: val_accuracy did not improve from 0.91282
# Epoch 91/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2191 - accuracy: 0.9386 - val_loss: 0.3093 - val_accuracy: 0.9128
#
# Epoch 00091: val_accuracy did not improve from 0.91282
# Epoch 92/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2193 - accuracy: 0.9376 - val_loss: 0.2993 - val_accuracy: 0.9162
#
# Epoch 00092: val_accuracy improved from 0.91282 to 0.91616, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-92-0.92.hdf5
# Epoch 93/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2234 - accuracy: 0.9361 - val_loss: 0.3066 - val_accuracy: 0.9113
#
# Epoch 00093: val_accuracy did not improve from 0.91616
# Epoch 94/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2211 - accuracy: 0.9380 - val_loss: 0.3032 - val_accuracy: 0.9128
#
# Epoch 00094: val_accuracy did not improve from 0.91616
# Epoch 95/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2203 - accuracy: 0.9364 - val_loss: 0.3002 - val_accuracy: 0.9117
#
# Epoch 00095: val_accuracy did not improve from 0.91616
# Epoch 96/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2209 - accuracy: 0.9383 - val_loss: 0.2972 - val_accuracy: 0.9146
#
# Epoch 00096: val_accuracy did not improve from 0.91616
# Epoch 97/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2268 - accuracy: 0.9369 - val_loss: 0.2998 - val_accuracy: 0.9124
#
# Epoch 00097: val_accuracy did not improve from 0.91616
# Epoch 98/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2284 - accuracy: 0.9379 - val_loss: 0.3014 - val_accuracy: 0.9115
#
# Epoch 00098: val_accuracy did not improve from 0.91616
# Epoch 99/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2170 - accuracy: 0.9370 - val_loss: 0.2998 - val_accuracy: 0.9144
#
# Epoch 00099: val_accuracy did not improve from 0.91616
# Epoch 100/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2131 - accuracy: 0.9395 - val_loss: 0.3036 - val_accuracy: 0.9104
#
# Epoch 00100: val_accuracy did not improve from 0.91616
# Epoch 101/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2257 - accuracy: 0.9339 - val_loss: 0.2991 - val_accuracy: 0.9135
#
# Epoch 00101: val_accuracy did not improve from 0.91616
# Epoch 102/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2072 - accuracy: 0.9421 - val_loss: 0.3053 - val_accuracy: 0.9072
#
# Epoch 00102: val_accuracy did not improve from 0.91616
# Epoch 103/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2118 - accuracy: 0.9416 - val_loss: 0.2998 - val_accuracy: 0.9126
#
# Epoch 00103: val_accuracy did not improve from 0.91616
# Epoch 104/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2164 - accuracy: 0.9381 - val_loss: 0.2959 - val_accuracy: 0.9151
#
# Epoch 00104: val_accuracy did not improve from 0.91616
# Epoch 105/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2109 - accuracy: 0.9415 - val_loss: 0.3028 - val_accuracy: 0.9126
#
# Epoch 00105: val_accuracy did not improve from 0.91616
# Epoch 106/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2065 - accuracy: 0.9395 - val_loss: 0.3029 - val_accuracy: 0.9110
#
# Epoch 00106: val_accuracy did not improve from 0.91616
# Epoch 107/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2043 - accuracy: 0.9435 - val_loss: 0.2983 - val_accuracy: 0.9115
#
# Epoch 00107: val_accuracy did not improve from 0.91616
# Epoch 108/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2138 - accuracy: 0.9398 - val_loss: 0.2990 - val_accuracy: 0.9130
#
# Epoch 00108: val_accuracy did not improve from 0.91616
# Epoch 109/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2160 - accuracy: 0.9388 - val_loss: 0.2935 - val_accuracy: 0.9155
#
# Epoch 00109: val_accuracy did not improve from 0.91616
# Epoch 110/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2118 - accuracy: 0.9386 - val_loss: 0.2980 - val_accuracy: 0.9128
#
# Epoch 00110: val_accuracy did not improve from 0.91616
# Epoch 111/200
# 1122/1122 [==============================] - 3s 2ms/step - loss: 0.2157 - accuracy: 0.9392 - val_loss: 0.2954 - val_accuracy: 0.9155
#
# Epoch 00111: val_accuracy did not improve from 0.91616
# Epoch 112/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2086 - accuracy: 0.9414 - val_loss: 0.2926 - val_accuracy: 0.9146
#
# Epoch 00112: val_accuracy did not improve from 0.91616
# Epoch 113/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2074 - accuracy: 0.9398 - val_loss: 0.2941 - val_accuracy: 0.9148
#
# Epoch 00113: val_accuracy did not improve from 0.91616
# Epoch 114/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2170 - accuracy: 0.9398 - val_loss: 0.2987 - val_accuracy: 0.9137
#
# Epoch 00114: val_accuracy did not improve from 0.91616
# Epoch 115/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2152 - accuracy: 0.9366 - val_loss: 0.3048 - val_accuracy: 0.9130
#
# Epoch 00115: val_accuracy did not improve from 0.91616
# Epoch 116/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2106 - accuracy: 0.9422 - val_loss: 0.2961 - val_accuracy: 0.9157
#
# Epoch 00116: val_accuracy did not improve from 0.91616
# Epoch 117/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1943 - accuracy: 0.9456 - val_loss: 0.2973 - val_accuracy: 0.9133
#
# Epoch 00117: val_accuracy did not improve from 0.91616
# Epoch 118/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2053 - accuracy: 0.9424 - val_loss: 0.2949 - val_accuracy: 0.9162
#
# Epoch 00118: val_accuracy did not improve from 0.91616
# Epoch 119/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2082 - accuracy: 0.9413 - val_loss: 0.2950 - val_accuracy: 0.9164
#
# Epoch 00119: val_accuracy improved from 0.91616 to 0.91639, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-119-0.92.hdf5
# Epoch 120/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2009 - accuracy: 0.9450 - val_loss: 0.2958 - val_accuracy: 0.9148
#
# Epoch 00120: val_accuracy did not improve from 0.91639
# Epoch 121/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2079 - accuracy: 0.9397 - val_loss: 0.3042 - val_accuracy: 0.9130
#
# Epoch 00121: val_accuracy did not improve from 0.91639
# Epoch 122/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2048 - accuracy: 0.9424 - val_loss: 0.2984 - val_accuracy: 0.9119
#
# Epoch 00122: val_accuracy did not improve from 0.91639
# Epoch 123/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2002 - accuracy: 0.9425 - val_loss: 0.2984 - val_accuracy: 0.9162
#
# Epoch 00123: val_accuracy did not improve from 0.91639
# Epoch 124/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2037 - accuracy: 0.9420 - val_loss: 0.3023 - val_accuracy: 0.9093
#
# Epoch 00124: val_accuracy did not improve from 0.91639
# Epoch 125/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2044 - accuracy: 0.9414 - val_loss: 0.2983 - val_accuracy: 0.9133
#
# Epoch 00125: val_accuracy did not improve from 0.91639
# Epoch 126/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2027 - accuracy: 0.9407 - val_loss: 0.2959 - val_accuracy: 0.9148
#
# Epoch 00126: val_accuracy did not improve from 0.91639
# Epoch 127/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2121 - accuracy: 0.9417 - val_loss: 0.2935 - val_accuracy: 0.9148
#
# Epoch 00127: val_accuracy did not improve from 0.91639
# Epoch 128/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1953 - accuracy: 0.9449 - val_loss: 0.2934 - val_accuracy: 0.9182
#
# Epoch 00128: val_accuracy improved from 0.91639 to 0.91817, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-128-0.92.hdf5
# Epoch 129/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1963 - accuracy: 0.9427 - val_loss: 0.2934 - val_accuracy: 0.9168
#
# Epoch 00129: val_accuracy did not improve from 0.91817
# Epoch 130/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1998 - accuracy: 0.9447 - val_loss: 0.2986 - val_accuracy: 0.9130
#
# Epoch 00130: val_accuracy did not improve from 0.91817
# Epoch 131/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1956 - accuracy: 0.9443 - val_loss: 0.2974 - val_accuracy: 0.9119
#
# Epoch 00131: val_accuracy did not improve from 0.91817
# Epoch 132/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1918 - accuracy: 0.9480 - val_loss: 0.2925 - val_accuracy: 0.9162
#
# Epoch 00132: val_accuracy did not improve from 0.91817
# Epoch 133/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1945 - accuracy: 0.9457 - val_loss: 0.2903 - val_accuracy: 0.9168
#
# Epoch 00133: val_accuracy did not improve from 0.91817
# Epoch 134/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2051 - accuracy: 0.9420 - val_loss: 0.2927 - val_accuracy: 0.9137
#
# Epoch 00134: val_accuracy did not improve from 0.91817
# Epoch 135/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2054 - accuracy: 0.9419 - val_loss: 0.2934 - val_accuracy: 0.9142
#
# Epoch 00135: val_accuracy did not improve from 0.91817
# Epoch 136/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.2163 - accuracy: 0.9405 - val_loss: 0.2933 - val_accuracy: 0.9175
#
# Epoch 00136: val_accuracy did not improve from 0.91817
# Epoch 137/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1943 - accuracy: 0.9441 - val_loss: 0.2912 - val_accuracy: 0.9164
#
# Epoch 00137: val_accuracy did not improve from 0.91817
# Epoch 138/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1988 - accuracy: 0.9459 - val_loss: 0.2901 - val_accuracy: 0.9171
#
# Epoch 00138: val_accuracy did not improve from 0.91817
# Epoch 139/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1923 - accuracy: 0.9456 - val_loss: 0.2937 - val_accuracy: 0.9151
#
# Epoch 00139: val_accuracy did not improve from 0.91817
# Epoch 140/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1967 - accuracy: 0.9449 - val_loss: 0.2953 - val_accuracy: 0.9151
#
# Epoch 00140: val_accuracy did not improve from 0.91817
# Epoch 141/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.2073 - accuracy: 0.9415 - val_loss: 0.2982 - val_accuracy: 0.9133
#
# Epoch 00141: val_accuracy did not improve from 0.91817
# Epoch 142/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1975 - accuracy: 0.9416 - val_loss: 0.2946 - val_accuracy: 0.9126
#
# Epoch 00142: val_accuracy did not improve from 0.91817
# Epoch 143/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1940 - accuracy: 0.9422 - val_loss: 0.2965 - val_accuracy: 0.9128
#
# Epoch 00143: val_accuracy did not improve from 0.91817
# Epoch 144/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1938 - accuracy: 0.9445 - val_loss: 0.3035 - val_accuracy: 0.9139
#
# Epoch 00144: val_accuracy did not improve from 0.91817
# Epoch 145/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1961 - accuracy: 0.9428 - val_loss: 0.2960 - val_accuracy: 0.9128
#
# Epoch 00145: val_accuracy did not improve from 0.91817
# Epoch 146/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1964 - accuracy: 0.9443 - val_loss: 0.2933 - val_accuracy: 0.9144
#
# Epoch 00146: val_accuracy did not improve from 0.91817
# Epoch 147/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1950 - accuracy: 0.9471 - val_loss: 0.2973 - val_accuracy: 0.9119
#
# Epoch 00147: val_accuracy did not improve from 0.91817
# Epoch 148/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1907 - accuracy: 0.9456 - val_loss: 0.2939 - val_accuracy: 0.9151
#
# Epoch 00148: val_accuracy did not improve from 0.91817
# Epoch 149/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1924 - accuracy: 0.9442 - val_loss: 0.2915 - val_accuracy: 0.9164
#
# Epoch 00149: val_accuracy did not improve from 0.91817
# Epoch 150/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1898 - accuracy: 0.9456 - val_loss: 0.2910 - val_accuracy: 0.9166
#
# Epoch 00150: val_accuracy did not improve from 0.91817
# Epoch 151/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1869 - accuracy: 0.9478 - val_loss: 0.2934 - val_accuracy: 0.9128
#
# Epoch 00151: val_accuracy did not improve from 0.91817
# Epoch 152/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1976 - accuracy: 0.9443 - val_loss: 0.2928 - val_accuracy: 0.9153
#
# Epoch 00152: val_accuracy did not improve from 0.91817
# Epoch 153/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1837 - accuracy: 0.9496 - val_loss: 0.2915 - val_accuracy: 0.9166
#
# Epoch 00153: val_accuracy did not improve from 0.91817
# Epoch 154/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1867 - accuracy: 0.9481 - val_loss: 0.3000 - val_accuracy: 0.9142
#
# Epoch 00154: val_accuracy did not improve from 0.91817
# Epoch 155/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1949 - accuracy: 0.9442 - val_loss: 0.2935 - val_accuracy: 0.9144
#
# Epoch 00155: val_accuracy did not improve from 0.91817
# Epoch 156/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1951 - accuracy: 0.9446 - val_loss: 0.2941 - val_accuracy: 0.9135
#
# Epoch 00156: val_accuracy did not improve from 0.91817
# Epoch 157/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1938 - accuracy: 0.9447 - val_loss: 0.2923 - val_accuracy: 0.9135
#
# Epoch 00157: val_accuracy did not improve from 0.91817
# Epoch 158/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1964 - accuracy: 0.9459 - val_loss: 0.2989 - val_accuracy: 0.9144
#
# Epoch 00158: val_accuracy did not improve from 0.91817
# Epoch 159/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1909 - accuracy: 0.9444 - val_loss: 0.2967 - val_accuracy: 0.9162
#
# Epoch 00159: val_accuracy did not improve from 0.91817
# Epoch 160/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1891 - accuracy: 0.9457 - val_loss: 0.2917 - val_accuracy: 0.9137
#
# Epoch 00160: val_accuracy did not improve from 0.91817
# Epoch 161/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1938 - accuracy: 0.9460 - val_loss: 0.2912 - val_accuracy: 0.9166
#
# Epoch 00161: val_accuracy did not improve from 0.91817
# Epoch 162/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1853 - accuracy: 0.9479 - val_loss: 0.2925 - val_accuracy: 0.9155
#
# Epoch 00162: val_accuracy did not improve from 0.91817
# Epoch 163/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1930 - accuracy: 0.9455 - val_loss: 0.2982 - val_accuracy: 0.9166
#
# Epoch 00163: val_accuracy did not improve from 0.91817
# Epoch 164/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1823 - accuracy: 0.9480 - val_loss: 0.3067 - val_accuracy: 0.9139
#
# Epoch 00164: val_accuracy did not improve from 0.91817
# Epoch 165/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1885 - accuracy: 0.9505 - val_loss: 0.2967 - val_accuracy: 0.9144
#
# Epoch 00165: val_accuracy did not improve from 0.91817
# Epoch 166/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1924 - accuracy: 0.9444 - val_loss: 0.2931 - val_accuracy: 0.9146
#
# Epoch 00166: val_accuracy did not improve from 0.91817
# Epoch 167/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1912 - accuracy: 0.9487 - val_loss: 0.2959 - val_accuracy: 0.9155
#
# Epoch 00167: val_accuracy did not improve from 0.91817
# Epoch 168/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1958 - accuracy: 0.9466 - val_loss: 0.2931 - val_accuracy: 0.9146
#
# Epoch 00168: val_accuracy did not improve from 0.91817
# Epoch 169/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1789 - accuracy: 0.9474 - val_loss: 0.2945 - val_accuracy: 0.9146
#
# Epoch 00169: val_accuracy did not improve from 0.91817
# Epoch 170/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1872 - accuracy: 0.9469 - val_loss: 0.2924 - val_accuracy: 0.9164
#
# Epoch 00170: val_accuracy did not improve from 0.91817
# Epoch 171/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1923 - accuracy: 0.9454 - val_loss: 0.2945 - val_accuracy: 0.9179
#
# Epoch 00171: val_accuracy did not improve from 0.91817
# Epoch 172/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1902 - accuracy: 0.9476 - val_loss: 0.2930 - val_accuracy: 0.9153
#
# Epoch 00172: val_accuracy did not improve from 0.91817
# Epoch 173/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1750 - accuracy: 0.9497 - val_loss: 0.2942 - val_accuracy: 0.9184
#
# Epoch 00173: val_accuracy improved from 0.91817 to 0.91839, saving model to c:\Users\SRIRAM\OneDrive\Documents\Personal\Academics\Final_Year_Project\Final-Year-Project\model\trained\distracted-173-0.92.hdf5
# Epoch 174/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1889 - accuracy: 0.9476 - val_loss: 0.2931 - val_accuracy: 0.9164
#
# Epoch 00174: val_accuracy did not improve from 0.91839
# Epoch 175/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1818 - accuracy: 0.9489 - val_loss: 0.2932 - val_accuracy: 0.9168
#
# Epoch 00175: val_accuracy did not improve from 0.91839
# Epoch 176/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1849 - accuracy: 0.9482 - val_loss: 0.2931 - val_accuracy: 0.9179
#
# Epoch 00176: val_accuracy did not improve from 0.91839
# Epoch 177/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1797 - accuracy: 0.9478 - val_loss: 0.2937 - val_accuracy: 0.9139
#
# Epoch 00177: val_accuracy did not improve from 0.91839
# Epoch 178/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1816 - accuracy: 0.9464 - val_loss: 0.2944 - val_accuracy: 0.9157
#
# Epoch 00178: val_accuracy did not improve from 0.91839
# Epoch 179/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1799 - accuracy: 0.9492 - val_loss: 0.2915 - val_accuracy: 0.9157
#
# Epoch 00179: val_accuracy did not improve from 0.91839
# Epoch 180/200
# 1122/1122 [==============================] - 2s 2ms/step - loss: 0.1840 - accuracy: 0.9459 - val_loss: 0.2928 - val_accuracy: 0.9166
#
# Epoch 00180: val_accuracy did not improve from 0.91839
# Epoch 181/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1873 - accuracy: 0.9483 - val_loss: 0.2934 - val_accuracy: 0.9155
#
# Epoch 00181: val_accuracy did not improve from 0.91839
# Epoch 182/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1878 - accuracy: 0.9481 - val_loss: 0.2982 - val_accuracy: 0.9124
#
# Epoch 00182: val_accuracy did not improve from 0.91839
# Epoch 183/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1881 - accuracy: 0.9461 - val_loss: 0.2947 - val_accuracy: 0.9179
#
# Epoch 00183: val_accuracy did not improve from 0.91839
# Epoch 184/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1878 - accuracy: 0.9493 - val_loss: 0.2925 - val_accuracy: 0.9159
#
# Epoch 00184: val_accuracy did not improve from 0.91839
# Epoch 185/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1778 - accuracy: 0.9504 - val_loss: 0.2954 - val_accuracy: 0.9182
#
# Epoch 00185: val_accuracy did not improve from 0.91839
# Epoch 186/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1964 - accuracy: 0.9455 - val_loss: 0.2947 - val_accuracy: 0.9135
#
# Epoch 00186: val_accuracy did not improve from 0.91839
# Epoch 187/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1781 - accuracy: 0.9504 - val_loss: 0.2980 - val_accuracy: 0.9148
#
# Epoch 00187: val_accuracy did not improve from 0.91839
# Epoch 188/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1890 - accuracy: 0.9496 - val_loss: 0.2948 - val_accuracy: 0.9173
#
# Epoch 00188: val_accuracy did not improve from 0.91839
# Epoch 189/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1799 - accuracy: 0.9494 - val_loss: 0.2928 - val_accuracy: 0.9168
#
# Epoch 00189: val_accuracy did not improve from 0.91839
# Epoch 190/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1824 - accuracy: 0.9481 - val_loss: 0.3013 - val_accuracy: 0.9142
#
# Epoch 00190: val_accuracy did not improve from 0.91839
# Epoch 191/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1856 - accuracy: 0.9464 - val_loss: 0.3002 - val_accuracy: 0.9122
#
# Epoch 00191: val_accuracy did not improve from 0.91839
# Epoch 192/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1764 - accuracy: 0.9500 - val_loss: 0.2999 - val_accuracy: 0.9122
#
# Epoch 00192: val_accuracy did not improve from 0.91839
# Epoch 193/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1866 - accuracy: 0.9474 - val_loss: 0.2948 - val_accuracy: 0.9166
#
# Epoch 00193: val_accuracy did not improve from 0.91839
# Epoch 194/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1739 - accuracy: 0.9512 - val_loss: 0.2967 - val_accuracy: 0.9133
#
# Epoch 00194: val_accuracy did not improve from 0.91839
# Epoch 195/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1795 - accuracy: 0.9489 - val_loss: 0.2932 - val_accuracy: 0.9155
#
# Epoch 00195: val_accuracy did not improve from 0.91839
# Epoch 196/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1852 - accuracy: 0.9475 - val_loss: 0.2972 - val_accuracy: 0.9142
#
# Epoch 00196: val_accuracy did not improve from 0.91839
# Epoch 197/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1860 - accuracy: 0.9499 - val_loss: 0.2976 - val_accuracy: 0.9144
#
# Epoch 00197: val_accuracy did not improve from 0.91839
# Epoch 198/200
# 1122/1122 [==============================] - 1s 1ms/step - loss: 0.1873 - accuracy: 0.9467 - val_loss: 0.3025 - val_accuracy: 0.9133
#
# Epoch 00198: val_accuracy did not improve from 0.91839
# Epoch 199/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1927 - accuracy: 0.9460 - val_loss: 0.3004 - val_accuracy: 0.9135
#
# Epoch 00199: val_accuracy did not improve from 0.91839
# Epoch 200/200
# 1122/1122 [==============================] - 2s 1ms/step - loss: 0.1717 - accuracy: 0.9511 - val_loss: 0.2987 - val_accuracy: 0.9137
#
# Epoch 00200: val_accuracy did not improve from 0.91839

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(model_history.history['loss'], color='b', label="Training loss")
ax1.plot(model_history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, 400, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(model_history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(model_history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, 400, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    fig.savefig(os.path.join(MODEL_PATH,"confusion_matrix.png"))
    return fig

# %%
def print_heatmap(n_labels, n_predictions, class_names):
    labels = n_labels #sess.run(tf.argmax(n_labels, 1))
    predictions = n_predictions #sess.run(tf.argmax(n_predictions, 1))

#     confusion_matrix = sess.run(tf.contrib.metrics.confusion_matrix(labels, predictions))
    matrix = confusion_matrix(labels.argmax(axis=1),predictions.argmax(axis=1))
    row_sum = np.sum(matrix, axis = 1)
    w, h = matrix.shape

    c_m = np.zeros((w, h))

    for i in range(h):
        c_m[i] = matrix[i] * 100 / row_sum[i]

    c = c_m.astype(dtype = np.uint8)

    
    heatmap = print_confusion_matrix(c, class_names, figsize=(18,10), fontsize=20)

# %%
class_names = list()
for name,idx in labels_id.items():
    class_names.append(name)
# print(class_names)
ypred = VGG16_model.predict(valid_vgg16,verbose=1)
# Out:
# 141/141 [==============================] - 0s 929us/step

# %%
print_heatmap(ytest,ypred,class_names)

# %%
ypred_class = np.argmax(ypred,axis=1)
# print(ypred_class[:10])
ytest = np.argmax(ytest,axis=1)

# %%
accuracy = accuracy_score(ytest,ypred_class)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(ytest, ypred_class,average='weighted')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(ytest,ypred_class,average='weighted')
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(ytest,ypred_class,average='weighted')
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.913712
# Precision: 0.914056
# Recall: 0.913712
# F1 score: 0.913565

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils.vis_utils import plot_model
from keras.models import load_model

model = load_model('model/vgg16/distracted-180-0.92.hdf5')
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')
